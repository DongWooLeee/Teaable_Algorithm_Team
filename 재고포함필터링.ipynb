# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import math
import random
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity


tea_db = (
  pd.read_csv(('C:/Users/Lee Dong woo/Desktop/Tea DB.csv'), encoding='cp949')
)
tea_db
# Out:
#      브랜드         제품 이름      차 종류         맛,향(필터링)        효능(필터링) 카페인 여부  \
# 0    알디프          밤의 차     블렌딩 티           달콤, 구수  기분전환, 안정 및 숙면     X
# 1    알디프          낮의 차     블렌딩 티        과일, 꽃, 달콤           기분전환      X
# 2    알디프        올드블랙매직     블렌딩 티               달콤           기분전환      O
# 3    알디프         비포 선셋     블렌딩 티               달콤       기분전환, 건강      X
# 4    알디프         무드포러브     블렌딩 티               과일           기분전환      O
# ..   ...           ...       ...              ...            ...    ...
# 92  찰스초이   레몬+오렌지+루이보스  과일차, 허브차      과일, 시트러스,허브        기분전환,소화      X
# 93  찰스초이    레몬+오렌지+레몬밤   과일차,허브차      과일, 시트러스,허브           기분전환      X
# 94  찰스초이   레몬+오렌지+페퍼민트   과일차, 모험  과일, 시트러스, 매운/민트        기분전환,소화      X
# 95  찰스초이  레몬+오렌지+히비스커스  과일차, 허브차     과일, 시트러스, 허브       기분전환,에너지      X
# 96  찰스초이     레몬+오렌지+자몽       과일차         과일, 시트러스           기분전환      X
#
#     1개당 가격  재고
# 0     1600   1
# 1     1600   7
# 2     1600  21
# 3     1600   5
# 4     1600   1
# ..     ...  ..
# 92    1400  19
# 93    1400   5
# 94    1400   1
# 95    1400   6
# 96    1400  20
#
# [97 rows x 8 columns]

# %%
tea_db
# Out:
#      브랜드         제품 이름      차 종류         맛,향(필터링)        효능(필터링) 카페인 여부  \
# 0    알디프          밤의 차     블렌딩 티           달콤, 구수  기분전환, 안정 및 숙면     X
# 1    알디프          낮의 차     블렌딩 티        과일, 꽃, 달콤           기분전환      X
# 2    알디프        올드블랙매직     블렌딩 티               달콤           기분전환      O
# 3    알디프         비포 선셋     블렌딩 티               달콤       기분전환, 건강      X
# 4    알디프         무드포러브     블렌딩 티               과일           기분전환      O
# ..   ...           ...       ...              ...            ...    ...
# 92  찰스초이   레몬+오렌지+루이보스  과일차, 허브차      과일, 시트러스,허브        기분전환,소화      X
# 93  찰스초이    레몬+오렌지+레몬밤   과일차,허브차      과일, 시트러스,허브           기분전환      X
# 94  찰스초이   레몬+오렌지+페퍼민트   과일차, 모험  과일, 시트러스, 매운/민트        기분전환,소화      X
# 95  찰스초이  레몬+오렌지+히비스커스  과일차, 허브차     과일, 시트러스, 허브       기분전환,에너지      X
# 96  찰스초이     레몬+오렌지+자몽       과일차         과일, 시트러스           기분전환      X
#
#     1개당 가격  재고
# 0     1600   1
# 1     1600   7
# 2     1600  21
# 3     1600   5
# 4     1600   1
# ..     ...  ..
# 92    1400  19
# 93    1400   5
# 94    1400   1
# 95    1400   6
# 96    1400  20
#
# [97 rows x 8 columns]

# %%
df=pd.DataFrame(tea_db)
df
# Out:
#      브랜드         제품 이름      차 종류         맛,향(필터링)        효능(필터링) 카페인 여부  \
# 0    알디프          밤의 차     블렌딩 티           달콤, 구수  기분전환, 안정 및 숙면     X
# 1    알디프          낮의 차     블렌딩 티        과일, 꽃, 달콤           기분전환      X
# 2    알디프        올드블랙매직     블렌딩 티               달콤           기분전환      O
# 3    알디프         비포 선셋     블렌딩 티               달콤       기분전환, 건강      X
# 4    알디프         무드포러브     블렌딩 티               과일           기분전환      O
# ..   ...           ...       ...              ...            ...    ...
# 92  찰스초이   레몬+오렌지+루이보스  과일차, 허브차      과일, 시트러스,허브        기분전환,소화      X
# 93  찰스초이    레몬+오렌지+레몬밤   과일차,허브차      과일, 시트러스,허브           기분전환      X
# 94  찰스초이   레몬+오렌지+페퍼민트   과일차, 모험  과일, 시트러스, 매운/민트        기분전환,소화      X
# 95  찰스초이  레몬+오렌지+히비스커스  과일차, 허브차     과일, 시트러스, 허브       기분전환,에너지      X
# 96  찰스초이     레몬+오렌지+자몽       과일차         과일, 시트러스           기분전환      X
#
#     1개당 가격  재고
# 0     1600   1
# 1     1600   7
# 2     1600  21
# 3     1600   5
# 4     1600   1
# ..     ...  ..
# 92    1400  19
# 93    1400   5
# 94    1400   1
# 95    1400   6
# 96    1400  20
#
# [97 rows x 8 columns]

# %%
user_teatype='녹차'
user_scent='고소시트'
user_effect='건강'
user_caff='O'

# %%
def type_filter(teatypes):
    user_typelist=[]
    
    for teatype in teatypes:
        if teatype in user_teatype:
            user_typelist.append(True)
        else:
            user_typelist.append(False)
    if np.sum(user_typelist)>=1:
        return True
    else:
        return False

# %%
def scent_filter(scents):
    user_scentlist=[]
    
    for scent in scents:
        if scent in user_scent:
            user_scentlist.append(True)
        else:
            user_scentlist.append(False)
    if np.sum(user_scentlist)>=1:
        return True
    else:
        return False

# %%
def effect_filter(effects):
    user_effectlist=[]
    
    for effect in effects:
        if effect in user_effect:
            user_effectlist.append(True)
        else:
            user_effectlist.append(False)
    if np.sum(user_effectlist)>=1:
        return True
    else:
        return False

# %%
def caff_filter(caffs):
    user_cafflist=[]
    for caff in caffs:
        if caff == user_caff:
            user_cafflist.append(True)
        else:
            user_cafflist.append(False)
    if np.sum(user_cafflist)>=1:
        return True
    else:
        return False

# %%
df.rename(columns={'맛,향(필터링)':'맛'},inplace=True)

# %%
df.rename(columns={'효능(필터링)':'효능'},inplace=True)
df.rename(columns={'카페인 여부':'카페인'},inplace=True)
df.rename(columns={'차 종류':'종류'},inplace=True)

# %%
df.맛.str.split(',')
df.효능.str.split(',')
df.종류.str.split('.')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   브랜드     97 non-null     object
#  1   제품 이름   97 non-null     object
#  2   종류      97 non-null     object
#  3   맛       97 non-null     object
#  4   효능      97 non-null     object
#  5   카페인     97 non-null     object
#  6   1개당 가격  97 non-null     int64
#  7   재고      97 non-null     int64
# dtypes: int64(2), object(6)
# memory usage: 6.2+ KB

# %%
df.카페인.apply(caff_filter).sum()
# Out:
# 49

# %%
df.효능.apply(effect_filter).sum()
# Out:
# 28

# %%
df.맛.apply(scent_filter).sum()
# Out:
# 37

# %%
df.종류.apply(type_filter).sum()
# Out:
# 73

# %%
cond_type=df.종류.apply(type_filter)
cond_effect=df.효능.apply(effect_filter)
cond_scent=df.맛.apply(scent_filter)
cond_caff=df.카페인.apply(caff_filter)
user_finalise=df[cond_type&cond_effect&cond_scent&cond_caff]
user_finalise
# Out:
#      브랜드     제품 이름      종류              맛        효능 카페인  1개당 가격  재고
# 74  보향다원  레몬그라스&진저      녹차       구수,매운/민트  건강,  추운날   O    1300   0
# 75  보향다원  마테&레몬그라스  홍차,허브차  구수, 허브, 매운/민트        건강   O    1300   2

# %%
len(user_finalise)
# Out:
# 2

# %%
user_finalise.sort_values(by='재고',axis=0,ascending=False)
# Out:
#      브랜드     제품 이름      종류              맛        효능 카페인  1개당 가격  재고
# 75  보향다원  마테&레몬그라스  홍차,허브차  구수, 허브, 매운/민트        건강   O    1300   2
# 74  보향다원  레몬그라스&진저      녹차       구수,매운/민트  건강,  추운날   O    1300   0

# %%
if len(user_finalise)>8:
    user_finalise=user_finalise.sort_values(by='재고',axis=0,ascending=False).head(8) 
else:
    user_finalise=df[cond_type&cond_scent&cond_caff].sort_values(by='재고',ascending=False).head(8)
    if len(user_finalise)<8:
        user_finalise=df[cond_type&cond_scent].sort_values(by='재고',ascending=False).head(8)
        if len(user_finalise)<8:
            user_finalise=df[cond_type].sort_values(by='재고',ascending=False).head(8)

# %%
user_finalise
# Out:
#              브랜드                제품 이름          종류              맛         효능  \
# 35  투티거스 호랑이 다과점                 로즈민트  블렌딩 티, 허브차      매운/민트, 허브    기분전환,소화
# 31  투티거스 호랑이 다과점                 레몬녹차          녹차           시트러스         소화
# 36  투티거스 호랑이 다과점                라벤더민트  블렌딩 티, 허브차      매운/민트, 허브    기분전환,소화
# 41        큐앤리브리즈               레모니 우롱         과일차           시트러스  다이어트및피부관리
# 12          티퍼런스               민트 퍼플티   블렌딩 티, 홍차          매운/민트         소화
# 90          찰스초이            레몬+오렌지+녹차     과일차, 녹차   과일, 시트러스, 구수    기분전환,소화
# 28  투티거스 호랑이 다과점  레몬 녹차 워터 제주 유기농 그린티          녹차       시트러스, 구수         소화
# 75          보향다원             마테&레몬그라스      홍차,허브차  구수, 허브, 매운/민트         건강
#
#    카페인  1개당 가격  재고
# 35   O    1600  21
# 31   O    1700  20
# 36   O    1600  19
# 41   O    1500  19
# 12   O    1800  15
# 90   O    1400  10
# 28   O    1700   9
# 75   O    1300   2

# %%
##매운/민트 에서 트가 시트러스랑 겹침..이거 내가 쓴 x in xs 써서 한글자라도 겹치면 안됨.

# %%
#### 향후 추천으로 넘어가자!
df['맛'].value_counts()
# Out:
# 구수                 19
# 시트러스               10
# 달콤                  5
# 과일                  4
# 꽃                   3
# 달콤, 구수              3
# 구수,꽃                3
# 달콤, 과일              3
# 달콤, 시트러스            2
# 매운/민트               2
# 과일, 달콤              2
# 매운/민트, 허브           2
# 과일, 시트러스, 구수        2
# 과일, 시트러스,허브         2
# 시트러스, 구수            2
# 구수, 허브              2
# 허브,꽃                2
# 허브                  1
# 과일,                 1
# 구수, 허브, 매운/민트       1
# 달콤, 허브              1
# 달콤,꽃                1
# 시트러스,꽃              1
# 달콤, 매운/민트, 과일       1
# 달콤, 시트러스, 과일        1
# 과일,달콤               1
# 과일, 시트러스, 매운/민트     1
# 허브, 매운/민트           1
# 시트러스,허브             1
# 구수,과일               1
# 허브, 과일, 달콤          1
# 과일, 꽃, 달콤           1
# 꽃, 구수               1
# 과일, 시트러스            1
# 달콤,구수               1
# 과일, 꽃               1
# 시트러스, 달콤, 과일        1
# 꽃,과일, 허브            1
# 구수,시트러스             1
# 시트러스, 과일            1
# 달콤, 꽃               1
# 과일, 시트러스, 허브        1
# 구수, 매운/민트           1
# 꽃, 과일               1
# 시트러스, 허브            1
# 구수,매운/민트            1
# Name: 맛, dtype: int64
