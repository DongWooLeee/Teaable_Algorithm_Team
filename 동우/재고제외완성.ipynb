# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import math
import random
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity


tea_db = (
  pd.read_csv(('C:/Users/Lee Dong woo/Desktop/Tea DB.csv'), encoding='cp949')
)
tea_db
# Out:
#       브랜드     제품 이름   차 종류   맛,향(필터링)        효능(필터링) 카페인 여부  1개당 가격
# 0     알디프      밤의 차  블랜딩 티     달콤, 구수  기분전환, 안정 및 숙면     X   1600.0
# 1     알디프      낮의 차  블랜딩 티  과일, 꽃, 달콤           기분전환      X  1600.0
# 2     알디프    올드블랙매직  블랜딩 티         달콤           기분전환      O  1600.0
# 3     알디프     비포 선셋  블랜딩 티         달콤       기분전환, 건강      X  1600.0
# 4     알디프     무드포러브  블랜딩 티         과일           기분전환      O  1600.0
# ..    ...       ...    ...        ...            ...    ...     ...
# 113  꽃차시대   샤인 캐모마일     꽃차          꽃           기분전환      X     NaN
# 114  꽃차시대  옐로크리치엔터멈     꽃차          꽃        안정 및 숙면      X     NaN
# 115  꽃차시대   파인 메리골드     꽃차          꽃     안정 및 숙면,건강      X     NaN
# 116  꽃차시대   애플 바이올렛     꽃차          꽃             건강      X     NaN
# 117  꽃차시대  메그놀리아 민트     꽃차          꽃             건강      X     NaN
#
# [118 rows x 7 columns]

# %%
tea_db
# Out:
#       브랜드     제품 이름   차 종류   맛,향(필터링)        효능(필터링) 카페인 여부  1개당 가격
# 0     알디프      밤의 차  블랜딩 티     달콤, 구수  기분전환, 안정 및 숙면     X   1600.0
# 1     알디프      낮의 차  블랜딩 티  과일, 꽃, 달콤           기분전환      X  1600.0
# 2     알디프    올드블랙매직  블랜딩 티         달콤           기분전환      O  1600.0
# 3     알디프     비포 선셋  블랜딩 티         달콤       기분전환, 건강      X  1600.0
# 4     알디프     무드포러브  블랜딩 티         과일           기분전환      O  1600.0
# ..    ...       ...    ...        ...            ...    ...     ...
# 113  꽃차시대   샤인 캐모마일     꽃차          꽃           기분전환      X     NaN
# 114  꽃차시대  옐로크리치엔터멈     꽃차          꽃        안정 및 숙면      X     NaN
# 115  꽃차시대   파인 메리골드     꽃차          꽃     안정 및 숙면,건강      X     NaN
# 116  꽃차시대   애플 바이올렛     꽃차          꽃             건강      X     NaN
# 117  꽃차시대  메그놀리아 민트     꽃차          꽃             건강      X     NaN
#
# [118 rows x 7 columns]

# %%
df=pd.DataFrame(tea_db)
df
# Out:
#       브랜드     제품 이름   차 종류   맛,향(필터링)        효능(필터링) 카페인 여부  1개당 가격
# 0     알디프      밤의 차  블랜딩 티     달콤, 구수  기분전환, 안정 및 숙면     X   1600.0
# 1     알디프      낮의 차  블랜딩 티  과일, 꽃, 달콤           기분전환      X  1600.0
# 2     알디프    올드블랙매직  블랜딩 티         달콤           기분전환      O  1600.0
# 3     알디프     비포 선셋  블랜딩 티         달콤       기분전환, 건강      X  1600.0
# 4     알디프     무드포러브  블랜딩 티         과일           기분전환      O  1600.0
# ..    ...       ...    ...        ...            ...    ...     ...
# 113  꽃차시대   샤인 캐모마일     꽃차          꽃           기분전환      X     NaN
# 114  꽃차시대  옐로크리치엔터멈     꽃차          꽃        안정 및 숙면      X     NaN
# 115  꽃차시대   파인 메리골드     꽃차          꽃     안정 및 숙면,건강      X     NaN
# 116  꽃차시대   애플 바이올렛     꽃차          꽃             건강      X     NaN
# 117  꽃차시대  메그놀리아 민트     꽃차          꽃             건강      X     NaN
#
# [118 rows x 7 columns]

# %%
df
# Out:
#       브랜드     제품 이름   차 종류   맛,향(필터링)        효능(필터링) 카페인 여부  1개당 가격
# 0     알디프      밤의 차  블랜딩 티     달콤, 구수  기분전환, 안정 및 숙면     X   1600.0
# 1     알디프      낮의 차  블랜딩 티  과일, 꽃, 달콤           기분전환      X  1600.0
# 2     알디프    올드블랙매직  블랜딩 티         달콤           기분전환      O  1600.0
# 3     알디프     비포 선셋  블랜딩 티         달콤       기분전환, 건강      X  1600.0
# 4     알디프     무드포러브  블랜딩 티         과일           기분전환      O  1600.0
# ..    ...       ...    ...        ...            ...    ...     ...
# 113  꽃차시대   샤인 캐모마일     꽃차          꽃           기분전환      X     NaN
# 114  꽃차시대  옐로크리치엔터멈     꽃차          꽃        안정 및 숙면      X     NaN
# 115  꽃차시대   파인 메리골드     꽃차          꽃     안정 및 숙면,건강      X     NaN
# 116  꽃차시대   애플 바이올렛     꽃차          꽃             건강      X     NaN
# 117  꽃차시대  메그놀리아 민트     꽃차          꽃             건강      X     NaN
#
# [118 rows x 7 columns]

# %%
user_scent='매운'
user_effect='건강'
user_caff='X'

# %%
def scent_filter(scents):
    user_scentlist=[]
    
    for scent in scents:
        if scent in user_scent:
            user_scentlist.append(True)
        else:
            user_scentlist.append(False)
    if np.sum(user_scentlist)>=1:
        return True
    else:
        return False

# %%
def effect_filter(effects):
    user_effectlist=[]
    
    for effect in effects:
        if effect in user_effect:
            user_effectlist.append(True)
        else:
            user_effectlist.append(False)
    if np.sum(user_effectlist)>=1:
        return True
    else:
        return False

# %%
def caff_filter(caffs):
    user_cafflist=[]
    for caff in caffs:
        if caff == user_caff:
            user_cafflist.append(True)
        else:
            user_cafflist.append(False)
    if np.sum(user_cafflist)>=1:
        return True
    else:
        return False

# %%
df.rename(columns={'맛,향(필터링)':'맛'},inplace=True)

# %%
df.rename(columns={'효능(필터링)':'효능'},inplace=True)
df.rename(columns={'카페인 여부':'카페인'},inplace=True)

# %%
df.맛.str.split(',')
df.효능.str.split(',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   브랜드     118 non-null    object
#  1   제품 이름   118 non-null    object
#  2   차 종류    118 non-null    object
#  3   맛       118 non-null    object
#  4   효능      118 non-null    object
#  5   카페인     118 non-null    object
#  6   1개당 가격  102 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 6.6+ KB

# %%
df.카페인.apply(caff_filter).sum()
# Out:
# 69

# %%
df.효능.apply(effect_filter).sum()
# Out:
# 34

# %%
df.맛.apply(scent_filter).sum()
# Out:
# 11

# %%
df.맛.apply(scent_filter).sum()
# Out:
# 11

# %%
cond_effect=df.효능.apply(effect_filter)
cond_scent=df.맛.apply(scent_filter)
cond_caff=df.카페인.apply(caff_filter)
user_finalise=df[cond_effect&cond_scent&cond_caff]
user_finalise
# Out:
#      브랜드      제품 이름      차 종류              맛           효능 카페인  1개당 가격
# 82  티퍼블릭  멜로우허브스파이스   전통차,허브차      매운/민트, 허브       추운날,건강   X  1500.0
# 93  프롬해빗      애플 민트  과일차, 허브차  달콤, 매운/민트, 과일  기분전환, 건강,소화   X   590.0

# %%
len(user_finalise)
# Out:
# 2

# %%
if len(user_finalise)>8:
    user_finallise=user_finalise.head(8) ## 차후 재고 데이터 대입했을 때 .loc['재고'].head(8)
else:
    user_finallise=df[cond_scent&cond_caff].head(8)
    if len(user_finallise)<8:
        user_finallise=df[cond_scent].head(8)

# %%
user_finallise
# Out:
#              브랜드       제품 이름        차 종류              맛        효능 카페인  1개당 가격
# 12          티퍼런스      민트 퍼플티   블랜딩 티, 홍차          매운/민트        소화   O  1800.0
# 14            꽃물       코지화이트   블렌딩 티, 꽃차          매운/민트      기분전환   X  1300.0
# 35  투티거스 호랑이 다과점        로즈민트  블랜딩 티, 허브차      매운/민트, 허브   기분전환,소화   O  1600.0
# 36  투티거스 호랑이 다과점       라벤더민트  블랜딩 티, 허브차      매운/민트, 허브   기분전환,소화   O  1600.0
# 71           루나틱       포근나잇         블랜딩티      구수, 매운/민트   안정 및 숙면   O  1245.0
# 74          보향다원    레몬그라스&진저          녹차       구수,매운/민트  건강,  추운날   O  1300.0
# 75          보향다원    마테&레몬그라스      홍차,허브차  구수, 허브, 매운/민트        건강   O  1300.0
# 78          보향다원  페퍼민트&레몬그라스         허브차      허브, 매운/민트   안정 및 숙면   X  1300.0

# %%
##매운/민트 에서 트가 시트러스랑 겹침..이거 내가 쓴 x in xs 써서 한글자라도 겹치면 안됨.
